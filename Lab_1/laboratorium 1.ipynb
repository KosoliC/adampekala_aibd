# %% [markdown]
# # Adam Pękala Laboratorium 1
#
# # Zadanie 3
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# f(x) = x^2 + 5
#
# 1. x > -1 oraz x <1
# 2. x > -6 oraz x <6
# 3. x > 0 oraz x <5

# %%
import matplotlib.pyplot as plt
import numpy as np 

def function(x):
    return x**2+5


x = np.arange(-10,10)
y = function(x)

plt.plot(x,y)
plt.xlim([-1, 1])
plt.xlabel("argumenty oś x")
plt.ylabel("wartości funkcji y")
plt.title("Wykres funkcji f(x) = x^2 + 5")
plt.legend("wykres funkcji")
plt.show()
plt.plot(x,y)
plt.xlim([-6, 6])
plt.xlabel("argumenty oś x")
plt.ylabel("wartości funkcji y")
plt.title("Wykres funkcji f(x) = x^2 + 5")
plt.legend("wykres funkcji")
plt.show()
plt.plot(x,y)
plt.xlim([0, 5])
plt.xlabel("argumenty oś x")
plt.ylabel("wartości funkcji y")
plt.title("Wykres funkcji f(x) = x^2 + 5")
plt.legend('wykres funkcji')
plt.show()

# %% [markdown]
# # Zadanie 4
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl
# informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
#Utworzenie dataframe
import pandas as pd

data = {
    "name": ['Adam','Rafał','Klaudia','Ola','Jakub'],
    "surname": ['Kowalski','Miłosz','Pękala','Tasak','Sacha'],
    "age": [23,21,42,32,18],
    "sex": ['Male','Male','Female','Female','Male']
}

df = pd.DataFrame(data)

print(df,'\n')
# Out:
#       name   surname  age     sex
# 0     Adam  Kowalski   23    Male
# 1    Rafał    Miłosz   21    Male
# 2  Klaudia    Pękala   42  Female
# 3      Ola     Tasak   32  Female
# 4    Jakub     Sacha   18    Male

# %%
# Informacje o dataframe
df.info(verbose=None, buf=None, max_cols=None,)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
# Opis danych
df.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
# Out:
#              age
# count   5.000000
# mean   27.200000
# std     9.782638
# min    18.000000
# 25%    21.000000
# 50%    23.000000
# 75%    32.000000
# max    42.000000

# %%
# Wyświetlenie pierwszych trzech rekordów
df.head(n=3)
# Out:
#       name   surname  age     sex
# 0     Adam  Kowalski   23    Male
# 1    Rafał    Miłosz   21    Male
# 2  Klaudia    Pękala   42  Female
